# %%
import os
from pathlib import Path

import pandas as pd

# %% [markdown]
# ## Load + Do Data Exploration

# %%
# traverse to root of repo dynamically
cwd = Path().cwd()
if "_FLAG_CWD_SET" not in globals():
  while cwd.name != "src":
    print("looking for repo root:", cwd.parent)
    cwd = cwd.parent
  os.chdir(cwd.parent)
print("In repo root:", Path().cwd())
_FLAG_CWD_SET = True
# Out:
# In repo root: /home/will/cs5100-project

# %%
# this assumes that you have already run the paprika parser code to code
# (see 'make build' for more details)
INPUT_PATH: Path = Path("resources/paprika/.export.paprikarecipes.parsed.json")
OUTPUT_PATH: Path = INPUT_PATH.parent / ".export.paprikarecipes.cleaned.json"
INPUT_PATH.absolute()
# Out:
# PosixPath('/home/will/cs5100-project/resources/paprika/.export.paprikarecipes.parsed.json')

# %%
df = pd.read_json(INPUT_PATH)
df = df.replace(r"^\s*$", pd.NA, regex=True)

# %%
print(f"{df.shape=}\n\n{df.columns=}")
# Out:
# df.shape=(424, 24)
#
# df.columns=Index(['uid', 'created', 'hash', 'name', 'description', 'ingredients',
#        'directions', 'notes', 'nutritional_info', 'prep_time', 'cook_time',
#        'total_time', 'difficulty', 'servings', 'rating', 'source',
#        'source_url', 'photo', 'photo_large', 'photo_hash', 'image_url',
#        'photo_data', 'photos', 'categories'],
#       dtype='object')

# %%
# from above we can see there may be some columns we don't need since this is purely a
# text based GUI/TUI the user will be talking with
df = df.drop(
  columns=[
    "photo_hash",
    "photos",
    "photo",
    "image_url",
    "photo_large",
    "photo_data",
    "hash",
    "uid",
  ]
)

print(f"{df.columns=}")
# Out:
# df.columns=Index(['created', 'name', 'description', 'ingredients', 'directions', 'notes',
#        'nutritional_info', 'prep_time', 'cook_time', 'total_time',
#        'difficulty', 'servings', 'rating', 'source', 'source_url',
#        'categories'],
#       dtype='object')

# %% [markdown]
# ### Summary Stats

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424 entries, 0 to 423
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   created           424 non-null    object
#  1   name              424 non-null    object
#  2   description       45 non-null     object
#  3   ingredients       398 non-null    object
#  4   directions        399 non-null    object
#  5   notes             71 non-null     object
#  6   nutritional_info  184 non-null    object
#  7   prep_time         237 non-null    object
#  8   cook_time         237 non-null    object
#  9   total_time        216 non-null    object
#  10  difficulty        219 non-null    object
#  11  servings          350 non-null    object
#  12  rating            424 non-null    int64
#  13  source            397 non-null    object
#  14  source_url        290 non-null    object
#  15  categories        424 non-null    object
# dtypes: int64(1), object(15)
# memory usage: 53.1+ KB

# %%
df.describe(include="all")  # for object columns
# Out:
#                     created                               name  \
# count                   424                                424
# unique                  424                                424
# top     2022-12-03 17:55:09  _Assorted Drinks Wines, Good Ones
# freq                      1                                  1
# mean                    NaN                                NaN
# std                     NaN                                NaN
# min                     NaN                                NaN
# 25%                     NaN                                NaN
# 50%                     NaN                                NaN
# 75%                     NaN                                NaN
# max                     NaN                                NaN
#
#                                                                                   description  \
# count                                                                                      45
# unique                                                                                     45
# top     Opal Apples - Idylwilde Acton April 2023\nAtaulfo Mangos - Idylwilde Acton April 2023
# freq                                                                                        1
# mean                                                                                      NaN
# std                                                                                       NaN
# min                                                                                       NaN
# 25%                                                                                       NaN
# 50%                                                                                       NaN
# 75%                                                                                       NaN
# max                                                                                       NaN
#
#                     ingredients               directions  \
# count                       398                      399
# unique                      398                      397
# top     [See additional photos]  [See additional photos]
# freq                          1                        3
# mean                        NaN                      NaN
# std                         NaN                      NaN
# min                         NaN                      NaN
# 25%                         NaN                      NaN
# 50%                         NaN                      NaN
# 75%                         NaN                      NaN
# max                         NaN                      NaN
#
#                                                                                                                           notes  \
# count                                                                                                                        71
# unique                                                                                                                       71
# top     *Skip water bc too much liquid --> flat cookies\n**originally 1tsp, but deemed coffee taste as overwhelming so cut down
# freq                                                                                                                          1
# mean                                                                                                                        NaN
# std                                                                                                                         NaN
# min                                                                                                                         NaN
# 25%                                                                                                                         NaN
# 50%                                                                                                                         NaN
# 75%                                                                                                                         NaN
# max                                                                                                                         NaN
#
#                                                          nutritional_info  \
# count                                                                 184
# unique                                                                184
# top     Calories 260\nFat 15g\nCarbs 28g\nFiber 1g\nSugar 16g\nProtein 3g
# freq                                                                    1
# mean                                                                  NaN
# std                                                                   NaN
# min                                                                   NaN
# 25%                                                                   NaN
# 50%                                                                   NaN
# 75%                                                                   NaN
# max                                                                   NaN
#
#        prep_time cook_time total_time difficulty servings      rating  \
# count        237       237        216        219      350  424.000000
# unique        44        82         54          3      122         NaN
# top        5 min    30 min     40 min       Easy        5         NaN
# freq          37        20         21        197       46         NaN
# mean         NaN       NaN        NaN        NaN      NaN    3.162736
# std          NaN       NaN        NaN        NaN      NaN    2.313375
# min          NaN       NaN        NaN        NaN      NaN    0.000000
# 25%          NaN       NaN        NaN        NaN      NaN    0.000000
# 50%          NaN       NaN        NaN        NaN      NaN    5.000000
# 75%          NaN       NaN        NaN        NaN      NaN    5.000000
# max          NaN       NaN        NaN        NaN      NaN    5.000000
#
#                      source  \
# count                   397
# unique                  100
# top     cooking.nytimes.com
# freq                    120
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN
#
#                                                                                                                                     source_url  \
# count                                                                                                                                      290
# unique                                                                                                                                     288
# top     https://www.blueapron.com/recipes/italian-style-pork-meatloaf-with-lemon-caper-roasted-vegetables-08bc7c5c-8fd9-43f5-8ee5-f14ea4d9280d
# freq                                                                                                                                         2
# mean                                                                                                                                       NaN
# std                                                                                                                                        NaN
# min                                                                                                                                        NaN
# 25%                                                                                                                                        NaN
# 50%                                                                                                                                        NaN
# 75%                                                                                                                                        NaN
# max                                                                                                                                        NaN
#
#            categories
# count             424
# unique            151
# top     [1'Main Dish]
# freq               66
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %%
# This code-block is from MISM3415 (data-mining) lecture
MAX_VALUES_TO_SHOW = 5

# for each column
for col in df.columns:
  print(col)

  # get a list of unique values, handling unhashable types like lists
  try:
    unique = df[col].unique()
  except TypeError:
    unique = pd.Series(
      df[col].apply(lambda x: str(x) if isinstance(x, list) else x)
    ).unique()

  # if number of unique values is less than 30, print the values. Otherwise print the
  # number of unique values
  # if len(unique) < MAX_VALUES_TO_SHOW:
  #   print(unique, "\n====================================\n\n")
  # else:

  print(unique[:MAX_VALUES_TO_SHOW])

  if len(unique) > MAX_VALUES_TO_SHOW:
    print(
      str(len(unique) - MAX_VALUES_TO_SHOW) + "more unique values",
      "\n====================================\n\n",
    )
# Out:
# created
# ['2022-12-03 17:55:09' '2023-04-08 17:08:59' '2023-10-06 18:29:49'
#  '2023-06-24 09:40:30' '2023-06-21 10:18:47']
# 419more unique values
# ====================================
#
#
# name
# ['_Assorted Drinks Wines, Good Ones' '_Assorted Fruit Mango, Apples'
#  '_Assorted Good Stuff' '_Assorted Sauces, Asian Sauces'
#  '_Assorted Spices, Cuban Goya Chicken Bouillon']
# 419more unique values
# ====================================
#
#
# description
# [<NA>
#  'Opal Apples - Idylwilde Acton April 2023\nAtaulfo Mangos - Idylwilde Acton April 2023'
#  'Yams Idylwilde April 2023'
#  'Alton Brown or La Terra Fina (Market Basket)'
#  'Make with [recipe:Pie Flaky Pie Crust], but this adds an extra 4.5 hrs to time! So if making for thanksgiving make first!']
# 41more unique values
# ====================================
#
#
# ingredients
# ['[See additional photos]' <NA>
#  '1 cup bread flour\n¾ cup all-purpose flour\n2 teaspoons kosher salt, or 1½ teaspoons table salt\n1 teaspoon baking soda\n1 cup unsalted butter (2 sticks)\n2 tablespoons water, room temperature*\n1 cup dark brown sugar\n½ cup white sugar\n2 teaspoons vanilla extract\n1/2 teaspoon espresso powder**\n1 large egg\n1 large egg yolk\n½ cup semi-sweet chocolate chips or chunks\n5 oz dark chocolate, chopped (Ghirardelli 60% Cacao)'
#  '1 cup thawed, chopped frozen spinach\n1 1/2 cups thawed, chopped frozen artichoke hearts\n6 ounces cream cheese\n1/4 cup sour cream\n1/4 cup mayonnaise\n1/3 cup grated Parmesan\n1/2 teaspoon red pepper flakes\n1/4 teaspoon salt\n1/4 teaspoon garlic powder'
#  "1 (9 inch) unbaked deep-dish pie crust\n¾ cup white sugar\n1 teaspoon ground cinnamon\n½ teaspoon salt\n½ teaspoon ground ginger\n¼ teaspoon ground cloves\n2 large eggs\n1 (15 ounce) can Libby's 100% Pure Pumpkin\n1 (12 fluid ounce) can Nestle Carnation Evaporated Milk"]
# 394more unique values
# ====================================
#
#
# directions
# ['[See additional photos]' <NA>
#  'Preheat the oven to 350˚F (180˚C).\n\nIn a medium bowl, sift together the **flours**, **salt**, and **baking** **soda**. Set aside.\n\nIn a medium or large saucepan, add the **butter** and melt over medium heat. The larger the pan you use, the quicker the process will be!\n\nBring the butter to a boil, stirring frequently. As the water begins to boil out of the butter, the milk solids in the butter will separate, sink to the bottom, and begin to toast and brown. As this begins to happen, make sure to stir constantly so the butter browns evenly. It may become quite foamy, splatter a bit, and be difficult to see, so keep a close eye on it, removing from heat and continuing to stir if it starts to foam over.\n\nOnce the butter has turned a nice nutty brown, remove from the heat and pour into a large liquid measuring cup to stop the cooking. Allow it to cool down for a minute or two, give it a stir, and carefully add 2-3 tablespoons of water to the butter to bring it back up to 1 cup (240 ml) of liquid.\n\nSet aside to cool to room temperature. To help speed this process up, you can place in the fridge for 10-15 minutes. You want to make sure the butter is still liquid when you’re adding it to the dough later on, so make sure to remove after 15 minutes.\n\nIn a large bowl, add the **sugars**, **vanilla**, **espresso powder**, and **cooled brown butter**. \nCream together with an electric hand mixer until light and fluffy, 1-2 minutes.\n\nAdd the **egg** and **yolk** and beat until incorporated.\n\nAdd the **dry ingredients, about ⅓ of the mixture at a time**, and beat between additions until just incorporated. It’s okay for there to be a bit of unmixed flour on the edge of bowl, this will be incorporated in the next step.\n\nUsing a wooden spoon, fold the **chocolate chips and chunks** into the dough\n\nScoop the cookies onto a parchment paper-lined baking sheet in 3-tablespoon-sized mounds.\n\nFor optimal flavor, cover and refrigerate for 1 hour or, even better, overnight.\n\nEvenly space the dough 3 inches (8 cm) apart from one another on a parchment paper-lined baking sheet.\n\nBake in a preheated 350˚F oven for 12-14 minutes.\n\nLet the cookies cool on the baking sheet for 2-3 minutes before transferring to a cooling rack to cool completely.\n\nEnjoy!\n\n[photo:3]'
#  'Boil **spinach** and **artichokes** in 1 cup of **water** until tender and drain. Discard liquid. \n\nHeat **cream cheese** in microwave for 1 minute or until hot and soft. \n\nStir in **rest of ingredients** and serve hot.'
#  'Gather the ingredients. Preheat the oven to 425 degrees F (220 degrees C).\n\nCombine sugar, cinnamon, salt, ginger, and cloves in small bowl.\n\nBeat eggs lightly in large bowl.\n\nStir in pumpkin and sugar-spice mixture.\n\nGradually stir in evaporated milk. Pour into pie shell.\n\nBake in the preheated oven for 15 minutes. Reduce temperature to 350 degrees F (175 degrees C) and continue to bake until a knife inserted near the center comes out clean, 40 to 50 more minutes. Remove from the oven and set on a wire rack to cool to room temperature.\n\nServe cooled pie immediately or refrigerate until ready to serve. (Do not freeze as this will cause the crust to separate from the filling.)']
# 393more unique values
# ====================================
#
#
# notes
# [<NA>
#  '*Skip water bc too much liquid --> flat cookies\n**originally 1tsp, but deemed coffee taste as overwhelming so cut down'
#  'Storage: Store any leftovers in an airtight container. They will last about 3-4 days in the fridge. When ready to eat, just microwave or toast the portion to be eaten.\n\nMake Ahead Tips: It’s best if you have cranberry sauce leftover to use in this recipe. It allows the cranberry sauce to settle and thicken, ensuring it remains put in the middle of the bread bowl on top of the cheese.\n\nSubstitutes: For best results, follow the recipe as is. However if you can’t find triple cream brie cheese, any other would be fine. It just wouldn’t be as melty as the triple cream. Also, if you don’t have any leftover cranberry sauce, you can substitute for jam of choice.'
#  'Only Mami liked!'
#  'If you are using frozen cranberries, there is no need to defrost before cooking.\n\nPull the sauce off the stove once you hear or see the first few cranberries burst. You want some of them to burst but others to remain whole for the best texture.\n\nThe sauce can be made up to 1 week in advance; keep refrigerated, and do not add the nuts until Thanksgiving Day, a few hours before serving.\n\nIf your sauce doesn’t set after you’ve chilled it, put it back on the stove and simmer it for another 5 minutes or so, then let it cool and chill. That should do the trick.\n\nMake it nonalcoholic, or play around with the flavor: Use 2 cups of orange juice, red wine, port or Madeira instead of the Lillet and the orange liqueur.\n\nYou can serve the jelly directly from a simple glass bowl, but the fun here is using different shaped molds. A small ornate Bundt pan is nice, and you can fill the center with sour cream or diced fresh pineapple. Pouring the jelly into clean empty cans is an amusing sleight of hand: “canned” cranberry sauce. Or pour the mixture into a plain metal bowl, then unmold it onto a fancy plate and surround it with a combination of dried cranberries and toasted pecan or walnut halves.\n\nMake sure the water your use to unmold your jelly is quite hot, not just warm. The idea is to melt the outer jelly layer enough so that the whole mold can slip right out.\n\nTo avoid drips, after dipping the cranberry jelly mold into the hot water, dry the outside of the mold with a kitchen towel before turning it onto your plate.\n\nIf you don’t have a food processor, you can make this with a meat or nut grinder. Or even a knife will work, though it will take you a while. Don’t use a blender, which will reduce everything to juice.\n\nDon’t overprocess the mixture. Pulse it just until it comes together. The chunky texture is part of its charm.\n\nMake this within 48 hours of serving. Unlike other cranberry sauces, it won’t get better sitting for longer than that, and if you use nuts, they will lose their crunch. If the liquid starts to pool, drain it off and give the whole thing a stir.']
# 67more unique values
# ====================================
#
#
# nutritional_info
# [<NA> 'Calories 260\nFat 15g\nCarbs 28g\nFiber 1g\nSugar 16g\nProtein 3g'
#  'Fat: 21g\nCalories: 245\nSaturated Fat: 9g\nSodium: 302mg\nFiber: 3g\nCholesterol: 44mg\nCarbohydrate: 9g\nSugar: 2g\nServing Size: 1 of 6 servings\nProtein: 7g'
#  '1 of 6 servings\nCalories: 646\nTotal Fat: 50\nSaturated Fat: 14\nCarbohydrates: 38\nDietary Fiber: 4\nSugar: 27\nProtein: 15\nCholesterol: 65\nSodium: 718'
#  'Calories: 122kcal, Carbohydrates: 7g, Protein: 6g, Fat: 7g, Saturated Fat: 4g, Cholesterol: 28mg, Sodium: 183mg, Potassium: 58mg, Sugar: 6g, Vitamin A: 260IU, Vitamin C: 3.1mg, Calcium: 59mg, Iron: 0.5mg']
# 180more unique values
# ====================================
#
#
# prep_time
# [<NA> '18 minutes' '10 min' '10 mins' '25 min']
# 40more unique values
# ====================================
#
#
# cook_time
# [<NA> '20 minutes' '5 min' '55 mins' '55 min']
# 78more unique values
# ====================================
#
#
# total_time
# [<NA> '1h 30min' '15 min' '5 min' '1 hr']
# 50more unique values
# ====================================
#
#
# difficulty
# [<NA> 'Easy' 'Medium' 'easy']
# servings
# [<NA> '18 cookies' 'Yield: 1 batch' '8' 'Yield: 6 servings']
# 118more unique values
# ====================================
#
#
# rating
# [1 5 0 4 2]
# 1more unique values
# ====================================
#
#
# source
# ['Casa Walling-Sotolongo' <NA> 'tasty.co' 'foodnetwork.com'
#  'allrecipes.com']
# 96more unique values
# ====================================
#
#
# source_url
# [<NA>
#  'https://tasty.co/recipe/tasty-101-ultimate-brown-butter-chocolate-chip-cookies'
#  'https://www.foodnetwork.com/recipes/alton-brown/hot-spinach-and-artichoke-dip-recipe-1912620'
#  'https://www.allrecipes.com/recipe/22755/libbys-famous-pumpkin-pie/'
#  'https://www.foodnetwork.com/recipes/food-network-kitchen/bacon-wrapped-brussels-sprouts-with-creamy-lemon-dip-3364562.amp']
# 284more unique values
# ====================================
#
#
# categories
# ['["1\'Drinks + Cocktails", \'_Try these\']'
#  '["1\'Appetizer + Snacks", "2\'Vegetables + Fruits", \'_Try these\']'
#  '[]' "['_Try these']" '["3\'Cuban", \'_Try these\']']
# 146more unique values
# ====================================

# %% [markdown]
# ## Cleansing

# %%
# Add new column for "been tried"
df["been_tried"] = df["rating"].apply(
  lambda x: False if x is None or x == "0" else True
)

# %%
# created currently str '2022-12-03 17:55:09' -> DateTime
from datetime import datetime

df["created"] = df["created"].apply(lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M:%S"))

# %%
pd.set_option("display.max_colwidth", 1000)
df["name"][df["name"].apply(lambda x: not x.isascii() or not x[0].isalpha())]
# Out:
# 0                                   _Assorted Drinks Wines, Good Ones
# 1                                       _Assorted Fruit Mango, Apples
# 2                                                _Assorted Good Stuff
# 3                                      _Assorted Sauces, Asian Sauces
# 4                       _Assorted Spices, Cuban Goya Chicken Bouillon
# 5                                                _Assorted Vegetables
# 6                    !!!*THE* Chocolate Chip Cookie Recipe (Lauren's)
# 7                         🦃 Dip Spinach Artichoke Dip (La Terra Fina)
# 8                                    🦃 Pie Libby's Famous Pumpkin Pie
# 9               🦃Bacon-Wrapped Brussels Sprouts with Creamy Lemon Dip
# 10                            🦃Dip Baked Brie Cranberry in Bread Bowl
# 11                               🦃Drink Apple Cider and Bourbon Punch
# 12                                    🦃Drink Apple Cider Apple Brandy
# 13                                     🦃Drink Cranberry Gin and Tonic
# 14                                        🦃Pie Pumpkin Pie, Revisited
# 15                                                    🦃Rice Wild Rice
# 16                                             🦃Sauce Cranberry Sauce
# 17                                               🦃Sauce Gravy (Heinz)
# 18                                                     🦃Side Stuffing
# 19                                                      🦃Turkey Roast
# 20                       🦃Vegetable Potatoes Ultimate Mashed Potatoes
# 21                                       🦃Vegetable Yams Candied Yams
# 32                                       Apple Crumble à la Air Fryer
# 43                              Asian Smacked Cucumber ‘Quick Kimchi’
# 86                     Breakfast Mom's Fluffy Pancakes & Mami’s Bacon
# 97      Cake Guinness Chocolate Cake with Bailey’s Cream Cheese Glaze
# 100                         Cake Million Heart Cheesecake Valentine’s
# 129                          Cobbler Chez Panisse’s Blueberry Cobbler
# 146                                  Cookies Snickerdoodles (Perli’s)
# 147                 Cookies🍪Chocolate Chip Cookies Quintessential NYT
# 163                                   Cuban Flan Abuelita Lily’s Flan
# 184                                        Cuban-ish Pollo en Fricasé
# 200         Dressing: Miso-Sesame Vinaigrette That’s Good on Anything
# 231                               Indian Aloo Chana 😋 (But No Tomato)
# 283                                                    Mexican Rice 😋
# 284                                                Mom’s Banana Bread
# 287           One Of Lauren’s Chocolate Chip Cookie Recipe (2nd Best)
# 294                                 Pasta Fettuccine Alfredo Lauren’s
# 316                              Peppers Stuffed Sweet Pepper ‘Boats’
# 320                                   Pie Nellie & Joe’s Key Lime Pie
# 329            Pork Glazed Grape and Jalapeño Roasted Pork Tenderloin
# 336                             Pudding Vanilla Crème Brûlée Lauren's
# 366                                                  Scones William’s
# 369    Seafood Provençal Salmon with Fennel, Rosemary and Orange Zest
# 383                              Soup Goya 16 Bean Soup (no Tomato 😋)
# 385                  Soup William’s Chipotle Chicken and Corn Chowder
# 401                                               Thick Mac N’ Cheese
# 413                Vegetable Potatoe Martha Stewart’s Mashed Potatoes
# 421                                             William’s Kimchi Rice
# Name: name, dtype: object

# %%
# drop rows of df[name] where starts with "_" since these are
# categories or labels in the given dataset
mask = df["name"].str.startswith("_")
print(f"dropping {mask.sum()} placeholder recipes")
df = df.loc[~mask].reset_index(drop=True)
# Out:
# dropping 6 placeholder recipes

# %%
# get rid of "fake" recipes
df["clean_name"] = df["name"]

non_ascii_subsitutions = {
  "’": "'",
  "‘": "'",
  "🦃": "(Thanksgiving)",
  "😋": " ",
  "🍪": " ",
  ",": ",",
  "!!!*THE*": "The",
}

# make character subsitutions for non_ascii_substitutions in df["clean_name"]
for src, dst in non_ascii_subsitutions.items():
  df["clean_name"] = df["clean_name"].str.replace(src, dst, regex=False)


df["clean_name"][df["clean_name"].apply(lambda x: not x.isascii())]
# Out:
# 26                                       Apple Crumble à la Air Fryer
# 178                                        Cuban-ish Pollo en Fricasé
# 323            Pork Glazed Grape and Jalapeño Roasted Pork Tenderloin
# 330                             Pudding Vanilla Crème Brûlée Lauren's
# 363    Seafood Provençal Salmon with Fennel, Rosemary and Orange Zest
# Name: clean_name, dtype: object

# %%
# categories is string of "["1\'Drinks + Cocktails", \'_Try these\']",
starting_tags = set()
ending_tags = set()


def parse_categories(s: list[str]) -> list[str]:
  cleaned = []
  for tag in s:
    starting_tags.add(tag)
    tag = tag.strip()

    # remove numeric prefix like 1' or 2'
    tag = tag.replace("’", "'")
    if "'" in tag and tag[0].isnumeric():
      tag = tag.split("'", 1)[1].strip()
    # remove leading underscore used for internal tags
    if tag.startswith("_"):
      tag = tag[1:]

    if len(tag) == 0:
      continue

    ending_tags.add(tag)
    cleaned.append(tag)
  return cleaned


# create a new column with parsed category lists
df["categories_parsed"] = df["categories"].apply(parse_categories)
print(f"{starting_tags=},\n {ending_tags=}")
# Out:
# starting_tags={"1'Dessert", '2’Cake', "3'Cuban", "1'Breakfast", "2'Salad", "1'Appetizer + Snacks", "1'Drinks + Cocktails", "3'Air Fryer", "_Lauren's", "New Year's Eve + Day", "2'Vegetables + Fruits", "3'Holidays", 'Noche Buena + Christmas', 'Thanksgiving', "2'Pasta", 'Easter', "1'Side Dish", "_William's", "1'Main Dish", '_Try these', "2'Rice", "_Perli's", "2'Soup Stews and Beans", "2'Sandwiches", "St Patrick's", "2'Bread"},
#  ending_tags={'Sandwiches', 'Cake', 'Pasta', "Perli's", 'Breakfast', 'Cuban', 'Appetizer + Snacks', 'Dessert', "New Year's Eve + Day", 'Salad', "Lauren's", 'Bread', 'Soup Stews and Beans', 'Holidays', 'Noche Buena + Christmas', 'Thanksgiving', 'Air Fryer', 'Rice', 'Main Dish', 'Easter', 'Vegetables + Fruits', "William's", 'Try these', "St Patrick's", 'Side Dish', 'Drinks + Cocktails'}

# %%
time_columns = ["prep_time", "cook_time", "total_time"]

for time_column in time_columns:
  print(f"\ncreating duration in minutes column for '{time_column}'")

  # try to convert disparate time formats
  temp = df[time_column].str.replace("mins", "minutes")
  temp = temp.str.replace("hrs", "hours")

  # remove bad formats
  temp = temp.mask(
    temp.str.contains(r"\b(?:or|chilling)\b", case=False, na=False), pd.NA
  )
  temp = temp.mask(temp.str.contains(r"[-–—\\\/:]", na=False), pd.NA)

  # show the amount of rows which could not be converted
  print(
    f"ignoring {temp.isna().sum() - df[time_column].isna().sum()}"
    " rows due to poor formatting"
  )

  # do basic time conversion
  temp = (pd.to_timedelta(temp).dt.total_seconds() // 60).astype(pd.Int64Dtype())
  df[f"{time_column}_min"] = temp
# Out:
# creating duration in minutes column for 'prep_time'
# ignoring 1 rows due to poor formatting
#
# creating duration in minutes column for 'cook_time'
# ignoring 7 rows due to poor formatting
#
# creating duration in minutes column for 'total_time'
# ignoring 0 rows due to poor formatting

# %%
df = df.dropna(
  subset=["notes", "directions", "description", "ingredients", "clean_name"],
  how="all",
)

# %%
df = df.convert_dtypes()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   created            418 non-null    datetime64[ns]
#  1   name               418 non-null    string
#  2   description        43 non-null     string
#  3   ingredients        397 non-null    string
#  4   directions         398 non-null    string
#  5   notes              71 non-null     string
#  6   nutritional_info   184 non-null    string
#  7   prep_time          237 non-null    string
#  8   cook_time          237 non-null    string
#  9   total_time         216 non-null    string
#  10  difficulty         219 non-null    string
#  11  servings           350 non-null    string
#  12  rating             418 non-null    Int64
#  13  source             396 non-null    string
#  14  source_url         290 non-null    string
#  15  categories         418 non-null    object
#  16  been_tried         418 non-null    boolean
#  17  clean_name         418 non-null    string
#  18  categories_parsed  418 non-null    object
#  19  prep_time_min      236 non-null    Int64
#  20  cook_time_min      230 non-null    Int64
#  21  total_time_min     216 non-null    Int64
# dtypes: Int64(4), boolean(1), datetime64[ns](1), object(2), string(14)
# memory usage: 71.2+ KB

# %%
df.describe(include="all")
# Out:
#                               created  \
# count                             418
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2023-07-21 14:18:30.208134144
# min               2022-11-26 09:25:46
# 25%        2022-11-27 10:50:42.500000
# 50%        2023-03-29 05:14:14.500000
# 75%     2024-03-24 19:24:44.750000128
# max               2025-05-30 19:35:00
# std                               NaN
#
#                                                     name  \
# count                                                418
# unique                                               418
# top     !!!*THE* Chocolate Chip Cookie Recipe (Lauren's)
# freq                                                   1
# mean                                                 NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
# std                                                  NaN
#
#                                          description  \
# count                                             43
# unique                                            43
# top     Alton Brown or La Terra Fina (Market Basket)
# freq                                               1
# mean                                             NaN
# min                                              NaN
# 25%                                              NaN
# 50%                                              NaN
# 75%                                              NaN
# max                                              NaN
# std                                              NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                        ingredients  \
# count                                                                                                                                                                                                                                                                                                                                                                                                                                          397
# unique                                                                                                                                                                                                                                                                                                                                                                                                                                         397
# top     1 cup bread flour\n¾ cup all-purpose flour\n2 teaspoons kosher salt, or 1½ teaspoons table salt\n1 teaspoon baking soda\n1 cup unsalted butter (2 sticks)\n2 tablespoons water, room temperature*\n1 cup dark brown sugar\n½ cup white sugar\n2 teaspoons vanilla extract\n1/2 teaspoon espresso powder**\n1 large egg\n1 large egg yolk\n½ cup semi-sweet chocolate chips or chunks\n5 oz dark chocolate, chopped (Ghirardelli 60% Cacao)
# freq                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# mean                                                                                                                                                                                                                                                                                                                                                                                                                                           NaN
# min                                                                                                                                                                                                                                                                                                                                                                                                                                            NaN
# 25%                                                                                                                                                                                                                                                                                                                                                                                                                                            NaN
# 50%                                                                                                                                                                                                                                                                                                                                                                                                                                            NaN
# 75%                                                                                                                                                                                                                                                                                                                                                                                                                                            NaN
# max                                                                                                                                                                                                                                                                                                                                                                                                                                            NaN
# std                                                                                                                                                                                                                                                                                                                                                                                                                                            NaN
#
#                      directions  \
# count                       398
# unique                      397
# top     [See additional photos]
# freq                          2
# mean                        NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN
# std                         NaN
#
#                                                                                                                           notes  \
# count                                                                                                                        71
# unique                                                                                                                       71
# top     *Skip water bc too much liquid --> flat cookies\n**originally 1tsp, but deemed coffee taste as overwhelming so cut down
# freq                                                                                                                          1
# mean                                                                                                                        NaN
# min                                                                                                                         NaN
# 25%                                                                                                                         NaN
# 50%                                                                                                                         NaN
# 75%                                                                                                                         NaN
# max                                                                                                                         NaN
# std                                                                                                                         NaN
#
#                                                          nutritional_info  \
# count                                                                 184
# unique                                                                184
# top     Calories 260\nFat 15g\nCarbs 28g\nFiber 1g\nSugar 16g\nProtein 3g
# freq                                                                    1
# mean                                                                  NaN
# min                                                                   NaN
# 25%                                                                   NaN
# 50%                                                                   NaN
# 75%                                                                   NaN
# max                                                                   NaN
# std                                                                   NaN
#
#        prep_time cook_time total_time  ...    rating               source  \
# count        237       237        216  ...     418.0                  396
# unique        44        82         54  ...      <NA>                  100
# top        5 min    30 min     40 min  ...      <NA>  cooking.nytimes.com
# freq          37        20         21  ...      <NA>                  120
# mean         NaN       NaN        NaN  ...   3.19378                  NaN
# min          NaN       NaN        NaN  ...       0.0                  NaN
# 25%          NaN       NaN        NaN  ...       0.0                  NaN
# 50%          NaN       NaN        NaN  ...       5.0                  NaN
# 75%          NaN       NaN        NaN  ...       5.0                  NaN
# max          NaN       NaN        NaN  ...       5.0                  NaN
# std          NaN       NaN        NaN  ...  2.315263                  NaN
#
#                                                                                                                                     source_url  \
# count                                                                                                                                      290
# unique                                                                                                                                     288
# top     https://www.blueapron.com/recipes/italian-style-pork-meatloaf-with-lemon-caper-roasted-vegetables-08bc7c5c-8fd9-43f5-8ee5-f14ea4d9280d
# freq                                                                                                                                         2
# mean                                                                                                                                       NaN
# min                                                                                                                                        NaN
# 25%                                                                                                                                        NaN
# 50%                                                                                                                                        NaN
# 75%                                                                                                                                        NaN
# max                                                                                                                                        NaN
# std                                                                                                                                        NaN
#
#            categories been_tried                                   clean_name  \
# count             418        418                                          418
# unique            146          1                                          418
# top     [1'Main Dish]       True  The Chocolate Chip Cookie Recipe (Lauren's)
# freq               66        418                                            1
# mean              NaN        NaN                                          NaN
# min               NaN        NaN                                          NaN
# 25%               NaN        NaN                                          NaN
# 50%               NaN        NaN                                          NaN
# 75%               NaN        NaN                                          NaN
# max               NaN        NaN                                          NaN
# std               NaN        NaN                                          NaN
#
#        categories_parsed prep_time_min cook_time_min  total_time_min
# count                418         236.0         230.0           216.0
# unique               146          <NA>          <NA>            <NA>
# top          [Main Dish]          <NA>          <NA>            <NA>
# freq                  66          <NA>          <NA>            <NA>
# mean                 NaN      21.09322     36.469565        67.37037
# min                  NaN           0.0           0.0             0.0
# 25%                  NaN           5.0          12.0            25.0
# 50%                  NaN          10.0          25.0            40.0
# 75%                  NaN          15.0          40.0            75.0
# max                  NaN        1440.0         525.0          1290.0
# std                  NaN     94.122599      51.79837      106.591774
#
# [11 rows x 22 columns]

# %%
df.to_json(OUTPUT_PATH, index=False, orient="records", indent=2)
